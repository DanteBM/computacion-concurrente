# %% [markdown]
# # Usando *mutex*
#
# De **mut**ual **ex**clusion, es una primitiva de sincronización que permite múltiples hilos compartir algún recurso pero no de manera simultánea

# %%
from threading import Thread, BoundedSemaphore, Lock
from queue import Queue
from random import randint

# %%
# Implementando con Lock
class Mutex:
    def __init__(self):
        self.esta_bloqueado = False
        self.lock = Lock()
    
    def bloquear(self):
        self.lock.acquire()
        self.esta_bloqueado = True
    
    def desbloquear(self):
        self.lock.release()
        self.esta_bloqueado = False

# %%
# Implementando con semáforos
class Mutex(BoundedSemaphore):
    def __init__(self):
        self.esta_bloqueado = False
        super().__init__(1) # Semáforo booleano
    
    def bloquear(self):
        super().acquire()
        self.esta_bloqueado = True
    
    def desbloquear(self):
        super().release()
        self.esta_bloqueado = False

# %%
class Productor(Thread):
    def __init__(self,buffer,mutex):
        super().__init__()
        self.buffer = buffer
        self.mutex = mutex
        self.esta_despierto = False
        
    def producir(self):
        item = randint(0,101)
        print(f'Productor: Acabo de producir {item}')
        return item
    
    def añadir_al_buffer(self,item):
        self.buffer.put(item)
        print(f'Productor: Agregué {item} al buffer')
    
    def run(self):
        while True:
            if not self.buffer.full():
                print(f'Productor: Hay espacio para nuevos items')
                item = self.producir()
                # Sección crítica
                self.mutex.bloquear()
                self.añadir_al_buffer(item)
                self.mutex.desbloquear()
                ##

# %%
class Consumidor(Thread):
    def __init__(self,buffer,mutex):
        super().__init__()
        self.buffer = buffer
        self.mutex = mutex
        self.esta_despierto = False
    
    def quitar_del_buffer(self):
        item = self.buffer.get()
        print(f'Consumidor: Obtuve {item} del buffer')
        return item
    
    def consumir(self,item):
        print(f'Consumidor: Consumí {item}')
    
    def run(self):
        while True:
            if not self.buffer.empty():
                print(f'Consumidor: Hay items por consumir')
                # Sección crítica
                self.mutex.bloquear()
                item = self.quitar_del_buffer()
                self.mutex.desbloquear()
                ##
                self.consumir(item)

# %%
mutex = Mutex()
buffer = Queue(5) # Tamaño del buffer

p = Productor(buffer,mutex)
c = Consumidor(buffer,mutex)

p.start()
c.start()

p.join()
c.join()
# Out:
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 36
# Productor: Agregué 36 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 8
# Productor: Agregué 8 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 96
# Productor: Agregué 96 al buffer
# Productor: Hay espacio para nuevos itemsConsumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61
# Consumidor: Hay items por consumir
#
# Productor: Acabo de producir 82
# Productor: Agregué 82 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 36 del buffer
# Consumidor: Consumí 36
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 8 del buffer
# Consumidor: Consumí 8
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 96 del buffer
# Consumidor: Consumí 96
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 82 del buffer
# Consumidor: Consumí 82
# Productor: Acabo de producir 75
# Productor: Agregué 75 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 93
# Consumidor: Obtuve 75 del buffer
# Consumidor: Consumí 75Productor: Agregué 93 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 60
# Productor: Agregué 60 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 98
# Productor: Agregué 98 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 18
# Productor: Agregué 18 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 93 del buffer
# Consumidor: Consumí 93
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 60 del buffer
# Consumidor: Consumí 60
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 98 del buffer
# Consumidor: Consumí 98
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 18 del buffer
# Consumidor: Consumí 18
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 53
# Productor: Agregué 53 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 20
# Productor: Agregué 20 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 71
# Productor: Agregué 71 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 98
# Productor: Agregué 98 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 27
# Productor: Agregué 27 al buffer
# Consumidor: Obtuve 53 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 65
#
# Consumidor: Consumí 53
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 71 del buffer
# Consumidor: Consumí 71
# Consumidor: Hay items por consumir
# Productor: Agregué 65 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 70Consumidor: Obtuve 98 del buffer
# Consumidor: Consumí 98
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 27 del buffer
# Consumidor: Consumí 27
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 65 del buffer
# Consumidor: Consumí 65
#
# Productor: Agregué 70 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 15
# Productor: Agregué 15 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 41
# Productor: Agregué 41 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 6
# Productor: Agregué 6 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 20
# Productor: Agregué 20 al buffer
#
# Consumidor: Obtuve 70 del buffer
# Consumidor: Consumí 70
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 14
# Productor: Agregué 14 al buffer
#
# Consumidor: Obtuve 15 del buffer
# Consumidor: Consumí 15
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 41 del buffer
# Consumidor: Consumí 41
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 80
# Productor: Agregué 80 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 35
# Productor: Agregué 35 al buffer
# Consumidor: Obtuve 6 del buffer
# Consumidor: Consumí 6
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 14 del buffer
# Consumidor: Consumí 14
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 80 del buffer
# Consumidor: Consumí 80
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 35 del buffer
# Consumidor: Consumí 35
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 8
# Productor: Agregué 8 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 13
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 8 del buffer
# Consumidor: Consumí 8
# Productor: Agregué 13 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 85
# Productor: Agregué 85 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 13 del buffer
# Consumidor: Consumí 13
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 85 del buffer
# Consumidor: Consumí 85
# Productor: Acabo de producir 5
# Productor: Agregué 5 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 71
# Productor: Agregué 71 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 45
# Productor: Agregué 45 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 55
# Productor: Agregué 55 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 8Consumidor: Hay items por consumir
# Productor: Agregué 8 al buffer
#
# Consumidor: Obtuve 5 del buffer
# Consumidor: Consumí 5
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 80
# Consumidor: Hay items por consumir
# Productor: Agregué 80 al buffer
# Consumidor: Obtuve 71 del buffer
# Productor: Hay espacio para nuevos itemsConsumidor: Consumí 71
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 45 del buffer
# Consumidor: Consumí 45
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 55 del buffer
# Consumidor: Consumí 55
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 8 del buffer
# Consumidor: Consumí 8
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 80 del buffer
# Consumidor: Consumí 80
#
# Productor: Acabo de producir 41
# Productor: Agregué 41 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 30
# Productor: Agregué 30 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 98
# Productor: Agregué 98 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 71
# Consumidor: Hay items por consumir
# Productor: Agregué 71 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 41 del buffer
# Consumidor: Consumí 41
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 30 del buffer
# Consumidor: Consumí 30
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 3
# Productor: Agregué 3 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 54
# Productor: Agregué 54 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 98 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 98
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 71 del buffer
# Consumidor: Consumí 71
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
#
# Productor: Acabo de producir 24
# Consumidor: Hay items por consumirProductor: Agregué 24 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 87
# Productor: Agregué 87 al buffer
# Productor: Hay espacio para nuevos items
#
# Productor: Acabo de producir 0
# Productor: Agregué 0 al buffer
# Consumidor: Obtuve 3 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 3
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 54 del buffer
# Consumidor: Consumí 54
# Consumidor: Hay items por consumir
#
# Productor: Acabo de producir 69
# Productor: Agregué 69 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 67Consumidor: Obtuve 24 del buffer
# Consumidor: Consumí 24
# Consumidor: Hay items por consumir
#
# Productor: Agregué 67 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 60
# Productor: Agregué 60 al buffer
# Consumidor: Obtuve 87 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 92
#
# Consumidor: Consumí 87
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 0 del buffer
# Consumidor: Consumí 0
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 69 del buffer
# Consumidor: Consumí 69
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 67 del buffer
# Consumidor: Consumí 67
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 60 del buffer
# Consumidor: Consumí 60
# Productor: Agregué 92 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 81
# Productor: Agregué 81 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 66
# Productor: Agregué 66 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 57
# Productor: Agregué 57 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 73
# Productor: Agregué 73 al bufferConsumidor: Hay items por consumir
#
# Consumidor: Obtuve 92 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 22
#
# Consumidor: Consumí 92
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 81 del buffer
# Consumidor: Consumí 81
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 66 del buffer
# Consumidor: Consumí 66
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 57 del buffer
# Consumidor: Consumí 57
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 73 del buffer
# Consumidor: Consumí 73
# Productor: Agregué 22 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 37
# Productor: Agregué 37 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 74
# Productor: Agregué 74 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 42
# Consumidor: Obtuve 22 del buffer
# Consumidor: Consumí 22
# Consumidor: Hay items por consumir
# Productor: Agregué 42 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 45
# Productor: Agregué 45 al buffer
# Productor: Hay espacio para nuevos items
#
# Consumidor: Obtuve 37 del buffer
# Consumidor: Consumí 37
# Productor: Acabo de producir 33Consumidor: Hay items por consumir
# Consumidor: Obtuve 74 del buffer
# Consumidor: Consumí 74
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 42 del buffer
# Consumidor: Consumí 42
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 45 del buffer
# Consumidor: Consumí 45
#
# Productor: Agregué 33 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 69
# Productor: Agregué 69 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 60
# Productor: Agregué 60 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 29
# Productor: Agregué 29 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 13
# Productor: Agregué 13 al buffer
# Consumidor: Obtuve 33 del buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 46
# Consumidor: Consumí 33
# Productor: Agregué 46 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 69 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 69
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 60 del buffer
# Consumidor: Consumí 60
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 29 del buffer
# Consumidor: Consumí 29
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 13 del buffer
# Consumidor: Consumí 13
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 46 del buffer
# Consumidor: Consumí 46
#
# Productor: Acabo de producir 3
# Productor: Agregué 3 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 20
# Productor: Agregué 20 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 5
# Productor: Agregué 5 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 40
# Productor: Agregué 40 al buffer
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 30
# Productor: Agregué 30 al buffer
# Consumidor: Obtuve 3 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 3
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 5 del buffer
# Consumidor: Consumí 5
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 40 del buffer
# Consumidor: Consumí 40
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 30 del buffer
# Consumidor: Consumí 30
#
# Productor: Acabo de producir 51
# Productor: Agregué 51 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 13
# Productor: Agregué 13 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 92
# Productor: Agregué 92 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 60
# Productor: Agregué 60 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Consumidor: Obtuve 51 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 69
# Consumidor: Consumí 51
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 13 del buffer
# Consumidor: Consumí 13
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 92 del buffer
# Consumidor: Consumí 92
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 60 del buffer
# Consumidor: Consumí 60
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 39 del buffer
# Consumidor: Consumí 39
#
# Productor: Agregué 69 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Productor: Acabo de producir 85Consumidor: Obtuve 69 del buffer
# Consumidor: Consumí 69
#
# Productor: Agregué 85 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 45
# Productor: Agregué 45 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 44
# Productor: Agregué 44 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 71
# Productor: Agregué 71 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 26Consumidor: Obtuve 85 del buffer
# Consumidor: Consumí 85
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 45 del buffer
# Consumidor: Consumí 45
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 44 del buffer
# Consumidor: Consumí 44
# Consumidor: Hay items por consumir
#
# Productor: Agregué 26 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 78
# Productor: Agregué 78 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 0
# Productor: Agregué 0 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 78
# Productor: Agregué 78 al buffer
# Consumidor: Obtuve 71 del buffer
# Consumidor: Consumí 71
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 6
# Productor: Agregué 6 al buffer
#
# Consumidor: Obtuve 26 del buffer
# Consumidor: Consumí 26
# Productor: Hay espacio para nuevos itemsConsumidor: Hay items por consumir
# Consumidor: Obtuve 78 del buffer
# Consumidor: Consumí 78
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 0 del buffer
# Consumidor: Consumí 0
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 78 del buffer
# Consumidor: Consumí 78
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 6 del buffer
# Consumidor: Consumí 6
#
# Productor: Acabo de producir 99
# Productor: Agregué 99 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 29
# Productor: Agregué 29 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 4
# Productor: Agregué 4 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 20Consumidor: Obtuve 99 del buffer
# Consumidor: Consumí 99
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 29 del buffer
# Consumidor: Consumí 29
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 4 del buffer
# Consumidor: Consumí 4
#
# Productor: Agregué 20 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
#
# Productor: Acabo de producir 56
# Productor: Agregué 56 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 84
# Productor: Agregué 84 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 68
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 56 del buffer
# Consumidor: Consumí 56
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 84 del buffer
# Consumidor: Consumí 84
# Productor: Agregué 68 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 43
# Productor: Agregué 43 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 82
# Productor: Agregué 82 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 79
# Productor: Agregué 79 al buffer
# Productor: Hay espacio para nuevos itemsConsumidor: Obtuve 68 del buffer
# Consumidor: Consumí 68
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 43 del buffer
# Consumidor: Consumí 43
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 82 del buffer
# Consumidor: Consumí 82
# Consumidor: Hay items por consumir
# Productor: Acabo de producir 89
# Productor: Agregué 89 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 48
# Productor: Agregué 48 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 95
# Productor: Agregué 95 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 67
# Productor: Agregué 67 al buffer
#
# Consumidor: Obtuve 79 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 30
#
# Consumidor: Consumí 79
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 48 del buffer
# Consumidor: Consumí 48
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 95 del buffer
# Consumidor: Consumí 95
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 67 del buffer
# Consumidor: Consumí 67
# Productor: Agregué 30 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 5
# Productor: Agregué 5 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 43
# Productor: Agregué 43 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 69
# Productor: Agregué 69 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 30 del bufferProductor: Hay espacio para nuevos items
#
# Productor: Acabo de producir 8
# Consumidor: Consumí 30Productor: Agregué 8 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 5 del buffer
# Consumidor: Consumí 5
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 43 del buffer
# Consumidor: Consumí 43
# Productor: Hay espacio para nuevos itemsConsumidor: Hay items por consumir
# Consumidor: Obtuve 69 del buffer
# Consumidor: Consumí 69
# Productor: Acabo de producir 12
# Productor: Agregué 12 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 16
#
# Consumidor: Hay items por consumir
# Productor: Agregué 16 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 76
# Productor: Agregué 76 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 8
# Productor: Agregué 8 al buffer
# Consumidor: Obtuve 8 del buffer
# Consumidor: Consumí 8
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 12 del buffer
# Consumidor: Consumí 12
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 16 del buffer
# Consumidor: Consumí 16
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 76 del buffer
# Consumidor: Consumí 76
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 8 del buffer
# Consumidor: Consumí 8
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 24
# Productor: Agregué 24 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 23
# Productor: Agregué 23 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 59
# Productor: Agregué 59 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 100Consumidor: Hay items por consumir
# Consumidor: Obtuve 24 del buffer
# Consumidor: Consumí 24
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 23 del buffer
# Consumidor: Consumí 23
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 59 del buffer
#
# Consumidor: Consumí 59
# Productor: Agregué 100 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 69
# Productor: Agregué 69 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 47
# Productor: Agregué 47 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 55
# Productor: Agregué 55 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 46
# Productor: Agregué 46 al buffer
#
# Consumidor: Obtuve 100 del bufferProductor: Hay espacio para nuevos items
#
# Consumidor: Consumí 100
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 69 del buffer
# Consumidor: Consumí 69
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 47 del buffer
# Consumidor: Consumí 47
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 55 del buffer
# Consumidor: Consumí 55
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 46 del buffer
# Consumidor: Consumí 46
# Productor: Acabo de producir 65
# Productor: Agregué 65 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 10
# Productor: Agregué 10 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 43
# Productor: Agregué 43 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 54
# Productor: Agregué 54 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 9
# Productor: Agregué 9 al buffer
#
# Consumidor: Obtuve 65 del buffer
# Consumidor: Consumí 65
# Productor: Hay espacio para nuevos itemsConsumidor: Hay items por consumir
# Consumidor: Obtuve 10 del buffer
# Consumidor: Consumí 10
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 43 del buffer
# Consumidor: Consumí 43
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 54 del buffer
# Consumidor: Consumí 54
# Consumidor: Hay items por consumir
#
# Productor: Acabo de producir 101Consumidor: Obtuve 9 del buffer
# Consumidor: Consumí 9
#
# Productor: Agregué 101 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 101 del buffer
# Consumidor: Consumí 101
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Productor: Acabo de producir 92
# Productor: Agregué 92 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos itemsConsumidor: Obtuve 92 del buffer
# Consumidor: Consumí 92
#
# Productor: Acabo de producir 79
# Productor: Agregué 79 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 84
# Productor: Agregué 84 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 6
# Productor: Agregué 6 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 58
# Productor: Agregué 58 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 79 del buffer
# Consumidor: Consumí 79
# Productor: Acabo de producir 59
# Productor: Agregué 59 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 3
# Productor: Agregué 3 al buffer
# Consumidor: Obtuve 84 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 84
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 6 del buffer
# Consumidor: Consumí 6
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 58 del buffer
# Consumidor: Consumí 58
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 59 del buffer
# Consumidor: Consumí 59
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 3 del buffer
# Consumidor: Consumí 3
#
# Productor: Acabo de producir 87
# Productor: Agregué 87 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 29
# Productor: Agregué 29 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 6
# Productor: Agregué 6 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 10
# Productor: Agregué 10 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 89
# Productor: Agregué 89 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 87 del buffer
# Consumidor: Consumí 87Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 94
# Productor: Agregué 94 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 29 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 66
#
# Consumidor: Consumí 29
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 6 del buffer
# Consumidor: Consumí 6
# Consumidor: Hay items por consumirProductor: Agregué 66 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
#
# Consumidor: Obtuve 10 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 74
#
# Consumidor: Consumí 10
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
# Productor: Agregué 74 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 94 del buffer
# Consumidor: Consumí 94
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 66 del buffer
# Consumidor: Consumí 66
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 74 del buffer
# Consumidor: Consumí 74
# Productor: Acabo de producir 47
# Productor: Agregué 47 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 4
# Productor: Agregué 4 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 24Consumidor: Obtuve 47 del buffer
# Consumidor: Consumí 47
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 4 del buffer
# Consumidor: Consumí 4
#
# Productor: Agregué 24 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 81
# Consumidor: Obtuve 24 del buffer
# Consumidor: Consumí 24
# Productor: Agregué 81 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 18
# Productor: Agregué 18 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 70
# Productor: Agregué 70 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 9Consumidor: Obtuve 81 del buffer
# Consumidor: Consumí 81
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 18 del buffer
# Consumidor: Consumí 18
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 70 del buffer
# Consumidor: Consumí 70
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61
#
# Productor: Agregué 9 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 18
# Productor: Agregué 18 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 53
# Productor: Agregué 53 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 78
# Productor: Agregué 78 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 78
# Productor: Agregué 78 al buffer
# Consumidor: Obtuve 9 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 9
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 18 del buffer
# Consumidor: Consumí 18
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 53 del buffer
# Consumidor: Consumí 53
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 78 del buffer
# Consumidor: Consumí 78
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 78 del buffer
# Consumidor: Consumí 78
#
# Productor: Acabo de producir 67
# Productor: Agregué 67 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 55
# Productor: Agregué 55 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 1
# Productor: Agregué 1 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 16
# Productor: Agregué 16 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 34
# Productor: Agregué 34 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 67 del bufferProductor: Hay espacio para nuevos items
#
# Consumidor: Consumí 67
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 55 del buffer
# Consumidor: Consumí 55
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 1 del buffer
# Consumidor: Consumí 1
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 16 del bufferProductor: Acabo de producir 89
#
# Consumidor: Consumí 16
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 34 del buffer
# Consumidor: Consumí 34
# Productor: Agregué 89 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 89 del bufferProductor: Acabo de producir 38
#
# Consumidor: Consumí 89
# Productor: Agregué 38 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 31
# Productor: Agregué 31 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 92
# Productor: Agregué 92 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 30
# Productor: Agregué 30 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 25
# Productor: Agregué 25 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 38 del buffer
# Consumidor: Consumí 38
# Productor: Hay espacio para nuevos itemsConsumidor: Hay items por consumir
# Consumidor: Obtuve 31 del buffer
# Consumidor: Consumí 31
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 92 del buffer
# Consumidor: Consumí 92
#
# Productor: Acabo de producir 26
# Productor: Agregué 26 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 98Consumidor: Hay items por consumir
#
# Consumidor: Obtuve 30 del buffer
# Consumidor: Consumí 30
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 25 del buffer
# Consumidor: Consumí 25
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 26 del buffer
# Consumidor: Consumí 26
# Productor: Agregué 98 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 14
# Productor: Agregué 14 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 41
# Productor: Agregué 41 al buffer
# Productor: Hay espacio para nuevos items
#
# Consumidor: Obtuve 98 del buffer
# Consumidor: Consumí 98
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 14 del buffer
# Consumidor: Consumí 14
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 41 del buffer
# Consumidor: Consumí 41
# Productor: Acabo de producir 75
# Productor: Agregué 75 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumirProductor: Acabo de producir 56
# Productor: Agregué 56 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 32
# Productor: Agregué 32 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 93
# Productor: Agregué 93 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 68
# Consumidor: Obtuve 75 del buffer
# Consumidor: Consumí 75
# Consumidor: Hay items por consumir
# Productor: Agregué 68 al buffer
# Productor: Hay espacio para nuevos items
#
# Productor: Acabo de producir 12
# Productor: Agregué 12 al buffer
# Consumidor: Obtuve 56 del buffer
# Consumidor: Consumí 56
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 32 del buffer
# Consumidor: Consumí 32
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 93 del buffer
# Consumidor: Consumí 93
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 68 del buffer
# Consumidor: Consumí 68
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 12 del buffer
# Consumidor: Consumí 12
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 16
# Productor: Agregué 16 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 76
#
# Consumidor: Obtuve 16 del buffer
# Consumidor: Consumí 16
# Productor: Agregué 76 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 34
# Productor: Agregué 34 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 38
# Productor: Agregué 38 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 7
# Productor: Agregué 7 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 15
# Productor: Agregué 15 al buffer
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 76 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 10
#
# Consumidor: Consumí 76
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 34 del buffer
# Consumidor: Consumí 34
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 38 del buffer
# Consumidor: Consumí 38
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 7 del buffer
# Consumidor: Consumí 7
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 15 del buffer
# Consumidor: Consumí 15
# Productor: Agregué 10 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 98
# Productor: Agregué 98 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 10 del bufferProductor: Acabo de producir 59
#
# Consumidor: Consumí 10
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 98 del buffer
# Consumidor: Consumí 98
# Productor: Agregué 59 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 59 del buffer
# Consumidor: Consumí 59
#
# Productor: Acabo de producir 78
# Productor: Agregué 78 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos itemsConsumidor: Obtuve 78 del buffer
# Consumidor: Consumí 78
#
# Productor: Acabo de producir 100
# Productor: Agregué 100 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 73
# Productor: Agregué 73 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 51
# Productor: Agregué 51 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 49
# Productor: Agregué 49 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 11
# Productor: Agregué 11 al buffer
#
# Consumidor: Obtuve 100 del bufferProductor: Hay espacio para nuevos items
#
# Consumidor: Consumí 100
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 73 del buffer
# Consumidor: Consumí 73
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 51 del buffer
# Consumidor: Consumí 51
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 49 del buffer
# Consumidor: Consumí 49
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 11 del buffer
# Consumidor: Consumí 11
# Productor: Acabo de producir 9
# Productor: Agregué 9 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 88
# Productor: Agregué 88 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 20
# Productor: Agregué 20 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 57
# Productor: Agregué 57 al buffer
# Consumidor: Obtuve 9 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 81
# Consumidor: Consumí 9
# Consumidor: Hay items por consumir
#
# Productor: Agregué 81 al buffer
# Consumidor: Obtuve 88 del buffer
# Consumidor: Consumí 88
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 85
# Consumidor: Hay items por consumirProductor: Agregué 85 al buffer
#
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 10
# Productor: Agregué 10 al buffer
#
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 57 del buffer
# Consumidor: Consumí 57
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 81 del buffer
# Consumidor: Consumí 81
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 85 del buffer
# Productor: Hay espacio para nuevos itemsConsumidor: Consumí 85
#
# Consumidor: Hay items por consumirProductor: Acabo de producir 67
# Productor: Agregué 67 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 6
# Productor: Agregué 6 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 29
# Productor: Agregué 29 al buffer
# Productor: Hay espacio para nuevos items
#
# Consumidor: Obtuve 10 del buffer
# Consumidor: Consumí 10
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 67 del buffer
# Consumidor: Consumí 67
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 6 del buffer
# Consumidor: Consumí 6
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 29 del buffer
# Consumidor: Consumí 29
# Productor: Acabo de producir 94
# Productor: Agregué 94 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 94
# Consumidor: Obtuve 94 del buffer
# Consumidor: Consumí 94
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 39 del buffer
#
# Consumidor: Consumí 39
# Productor: Agregué 94 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 22
# Productor: Agregué 22 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 94 del bufferProductor: Acabo de producir 100
#
# Consumidor: Consumí 94
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 22 del buffer
# Consumidor: Consumí 22
# Productor: Agregué 100 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 66
#
# Consumidor: Obtuve 100 del buffer
# Consumidor: Consumí 100
# Productor: Agregué 66 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 3
# Productor: Agregué 3 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 14
# Productor: Agregué 14 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 51
# Productor: Agregué 51 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 88
# Productor: Agregué 88 al buffer
# Consumidor: Obtuve 66 del buffer
# Consumidor: Consumí 66
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 86
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 3 del buffer
# Consumidor: Consumí 3
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 14 del buffer
# Consumidor: Consumí 14Productor: Agregué 86 al buffer
# Consumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 36
# Consumidor: Obtuve 51 del buffer
# Consumidor: Consumí 51Productor: Agregué 36 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 16
# Productor: Agregué 16 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 88 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 88
# Consumidor: Hay items por consumir
#
# Productor: Acabo de producir 96
# Productor: Agregué 96 al buffer
# Consumidor: Obtuve 86 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 86
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 36 del buffer
# Consumidor: Consumí 36
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 16 del buffer
# Consumidor: Consumí 16
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 96 del buffer
# Consumidor: Consumí 96
#
# Productor: Acabo de producir 7
# Productor: Agregué 7 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 11
# Productor: Agregué 11 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 4
# Productor: Agregué 4 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 12
# Productor: Agregué 12 al buffer
#
# Consumidor: Obtuve 7 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 7
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 39 del buffer
# Consumidor: Consumí 39
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 11 del buffer
# Consumidor: Consumí 11
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 4 del buffer
# Consumidor: Consumí 4
#
# Productor: Acabo de producir 25
# Productor: Agregué 25 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 89
# Productor: Agregué 89 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 52
# Productor: Agregué 52 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 12 del buffer
# Consumidor: Consumí 12
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 25 del buffer
# Consumidor: Consumí 25
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
# Consumidor: Hay items por consumir
# Productor: Acabo de producir 64
# Productor: Agregué 64 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 11
# Consumidor: Obtuve 52 del buffer
# Consumidor: Consumí 52
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 64 del buffer
# Consumidor: Consumí 64
# Productor: Agregué 11 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 36
# Productor: Agregué 36 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 38
# Productor: Agregué 38 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 9
# Productor: Agregué 9 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Obtuve 11 del buffer
# Consumidor: Consumí 11
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 36 del buffer
# Consumidor: Consumí 36
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 38 del buffer
# Consumidor: Consumí 38
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 9 del buffer
# Consumidor: Consumí 9
# Productor: Acabo de producir 20
# Productor: Agregué 20 al buffer
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 60
# Consumidor: Obtuve 20 del buffer
# Consumidor: Consumí 20
# Productor: Agregué 60 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 17
# Productor: Agregué 17 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 89
# Consumidor: Obtuve 60 del buffer
# Consumidor: Consumí 60Productor: Agregué 89 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 3
# Productor: Agregué 3 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 94
# Consumidor: Hay items por consumir
#
# Productor: Agregué 94 al buffer
# Consumidor: Obtuve 17 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 17
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
# Productor: Acabo de producir 5
# Productor: Agregué 5 al buffer
#
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 85
# Productor: Agregué 85 al buffer
# Consumidor: Obtuve 3 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 83
#
# Consumidor: Consumí 3
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Consumidor: Hay items por consumirProductor: Agregué 83 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 45
# Productor: Agregué 45 al buffer
#
# Consumidor: Obtuve 94 del buffer
# Consumidor: Consumí 94
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Consumidor: Obtuve 5 del buffer
# Consumidor: Consumí 5
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 85 del buffer
# Consumidor: Consumí 85
# Consumidor: Hay items por consumir
# Productor: Acabo de producir 94
# Productor: Agregué 94 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 27
# Productor: Agregué 27 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 23
# Productor: Agregué 23 al buffer
#
# Consumidor: Obtuve 83 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 83
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 45 del buffer
# Consumidor: Consumí 45
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 94 del buffer
# Consumidor: Consumí 94
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 27 del buffer
#
# Consumidor: Consumí 27
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 23 del buffer
# Consumidor: Consumí 23
# Productor: Acabo de producir 44
# Productor: Agregué 44 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 48
# Productor: Agregué 48 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 99
# Productor: Agregué 99 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 55
# Productor: Agregué 55 al buffer
# Consumidor: Obtuve 44 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 18
#
# Consumidor: Consumí 44Productor: Agregué 18 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 61
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 48 del buffer
# Consumidor: Consumí 48
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 99 del buffer
# Consumidor: Consumí 99
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 55 del buffer
# Consumidor: Consumí 55
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 18 del buffer
# Consumidor: Consumí 18
#
# Productor: Acabo de producir 93
# Productor: Agregué 93 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 10
# Productor: Agregué 10 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 65
# Productor: Agregué 65 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 83
# Productor: Agregué 83 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 53
# Productor: Agregué 53 al buffer
#
# Consumidor: Obtuve 93 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 89
#
# Consumidor: Consumí 93
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 10 del buffer
# Consumidor: Consumí 10
# Consumidor: Hay items por consumir
# Productor: Agregué 89 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 28
# Productor: Agregué 28 al buffer
# Consumidor: Obtuve 65 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 25
#
# Consumidor: Consumí 65
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 83 del buffer
# Consumidor: Consumí 83
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 53 del buffer
# Consumidor: Consumí 53
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 28 del buffer
# Consumidor: Consumí 28
# Productor: Agregué 25 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 64
# Productor: Agregué 64 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 56
# Productor: Agregué 56 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 26
# Productor: Agregué 26 al buffer
#
# Consumidor: Obtuve 25 del buffer
# Consumidor: Consumí 25
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 64 del buffer
# Consumidor: Consumí 64
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos itemsConsumidor: Obtuve 39 del buffer
# Consumidor: Consumí 39
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 56 del buffer
# Consumidor: Consumí 56
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 26 del buffer
# Consumidor: Consumí 26
#
# Productor: Acabo de producir 89
# Productor: Agregué 89 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 46Consumidor: Obtuve 89 del buffer
# Consumidor: Consumí 89
#
# Productor: Agregué 46 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 64
# Productor: Agregué 64 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 70
# Productor: Agregué 70 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 46 del buffer
# Consumidor: Consumí 46
# Consumidor: Hay items por consumirProductor: Acabo de producir 21
# Productor: Agregué 21 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 81
# Productor: Agregué 81 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 56
# Productor: Agregué 56 al buffer
#
# Consumidor: Obtuve 64 del bufferProductor: Hay espacio para nuevos items
#
# Productor: Acabo de producir 62
# Consumidor: Consumí 64Productor: Agregué 62 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 70 del bufferProductor: Hay espacio para nuevos items
# Consumidor: Consumí 70
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 21 del buffer
# Consumidor: Consumí 21
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 81 del buffer
# Consumidor: Consumí 81
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 56 del buffer
# Consumidor: Consumí 56
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 62 del buffer
# Consumidor: Consumí 62
#
# Productor: Acabo de producir 50
# Productor: Agregué 50 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 50 del buffer
# Consumidor: Consumí 50
# Productor: Acabo de producir 49
# Productor: Agregué 49 al bufferConsumidor: Hay items por consumir
#
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 35
# Productor: Agregué 35 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 43
# Productor: Agregué 43 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 17
# Productor: Agregué 17 al buffer
# Consumidor: Obtuve 49 del buffer
# Productor: Hay espacio para nuevos itemsConsumidor: Consumí 49
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 35 del buffer
# Consumidor: Consumí 35
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 43 del buffer
# Consumidor: Consumí 43
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 17 del buffer
# Consumidor: Consumí 17
#
# Productor: Acabo de producir 33
# Productor: Agregué 33 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 77
# Productor: Agregué 77 al buffer
# Productor: Hay espacio para nuevos items
#
# Consumidor: Obtuve 33 del buffer
# Productor: Acabo de producir 94
# Consumidor: Consumí 33
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 77 del buffer
# Consumidor: Consumí 77
# Productor: Agregué 94 al bufferConsumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 46
# Productor: Agregué 46 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 66
# Productor: Agregué 66 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 74
# Productor: Agregué 74 al buffer
#
# Consumidor: Obtuve 94 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 96
#
# Consumidor: Consumí 94
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 46 del buffer
# Consumidor: Consumí 46
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 66 del buffer
# Consumidor: Consumí 66
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 74 del buffer
# Consumidor: Consumí 74
# Productor: Agregué 96 al buffer
# Consumidor: Hay items por consumirProductor: Hay espacio para nuevos items
# Consumidor: Obtuve 96 del buffer
# Consumidor: Consumí 96
#
# Productor: Acabo de producir 72
# Productor: Agregué 72 al buffer
# Productor: Hay espacio para nuevos items
# Consumidor: Hay items por consumir
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 61
# Productor: Agregué 61 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 14
# Productor: Agregué 14 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 27
# Productor: Agregué 27 al buffer
# Consumidor: Obtuve 72 del bufferProductor: Hay espacio para nuevos items
# Productor: Acabo de producir 86
#
# Consumidor: Consumí 72
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 39 del buffer
# Consumidor: Consumí 39
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 61 del buffer
# Consumidor: Consumí 61Productor: Agregué 86 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 52
# Productor: Agregué 52 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 38
# Productor: Agregué 38 al buffer
#
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 14 del buffer
# Consumidor: Consumí 14
# Consumidor: Hay items por consumir
# Consumidor: Obtuve 27 del buffer
# Consumidor: Consumí 27
# Consumidor: Hay items por consumir
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 39
# Productor: Agregué 39 al buffer
# Productor: Hay espacio para nuevos items
# Productor: Acabo de producir 49
# Productor: Agregué 49 al buffer
